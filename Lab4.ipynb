# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'D:\1 та 2 семестр\2 курс\Питон\DataScince\NationalN\NationalNames.csv')

# %%
#Ex1

df[0:8]
# Out:
#    Id       Name  Year Gender  Count
# 0   1       Mary  1880      F   7065
# 1   2       Anna  1880      F   2604
# 2   3       Emma  1880      F   2003
# 3   4  Elizabeth  1880      F   1939
# 4   5     Minnie  1880      F   1746
# 5   6   Margaret  1880      F   1578
# 6   7        Ida  1880      F   1472
# 7   8      Alice  1880      F   1414

# %%
#Ex3
df.columns
# Out:
# Index(['Id', 'Name', 'Year', 'Gender', 'Count'], dtype='object')

# %%
#Ex6
df.groupby(['Gender'])[['Name']].nunique()
# Out:
#          Name
# Gender
# F       64911
# M       39199

# %%
#Ex7
df[(df['Gender'] == 'M') & (df['Year'] == 2010) ].head()
# Out:
#               Id     Name  Year Gender  Count
# 1677392  1677393    Jacob  2010      M  22082
# 1677393  1677394    Ethan  2010      M  17985
# 1677394  1677395  Michael  2010      M  17308
# 1677395  1677396   Jayden  2010      M  17152
# 1677396  1677397  William  2010      M  17030

# %%
#Ex8
#both_df = df.groupby("Year").sum()
#both_df.max()["Count"]
#print(both_df.idxmax()["Count"])
#df['Count'].max()
a =df[df['Count'] == 99680]
print(a['Name'])
# Out:
# 431052    Linda
# Name: Name, dtype: object

# %%
#Ex12
a2= df.groupby("Year")[["Name"]].nunique()
a2[a2["Name"]==32488] #2008

a2 = df[df["Year"]==2008]["Count"].max()

a2  = df[df["Count"] == 22568]
a2["Name"]

#df.groupby('Name')['Count'].mean().sort_values(ascending= False)[:1].index[0]
# Out:
# 1608302    Jacob
# Name: Name, dtype: object

# %%
#Ex13
df[(df['Name'] == 'Jacob') & (df['Gender'] == 'F') & (df['Count'] == 171)]
# Out:
#               Id   Name  Year Gender  Count
# 1455556  1455557  Jacob  2004      F    171

# %%
#Ex15
df.groupby('Year')[['Count']].sum()
# Out:
#         Count
# Year
# 1880   201484
# 1881   192699
# 1882   221538
# 1883   216950
# 1884   243467
# ...       ...
# 2010  3686589
# 2011  3646730
# 2012  3643336
# 2013  3626802
# 2014  3670151
#
# [135 rows x 1 columns]

# %%
#Ex16

a =df.groupby(['Year' ])[['Count']].sum()
a["Count"].max()
a = a[a["Count"]==4200026]
a
# Out:
#         Count
# Year
# 1957  4200026

# %%
#Ex17
df.groupby(['Year' , 'Gender'])['Count'].sum().unstack()
# Out:
# Gender        F        M
# Year
# 1880      90993   110491
# 1881      91954   100745
# 1882     107850   113688
# 1883     112321   104629
# 1884     129022   114445
# ...         ...      ...
# 2010    1772738  1913851
# 2011    1753500  1893230
# 2012    1753922  1889414
# 2013    1745339  1881463
# 2014    1768775  1901376
#
# [135 rows x 2 columns]

# %%
#Ex19
total_births = pd.pivot_table(df,index='Year', columns='Gender',values='Count',  aggfunc=sum).plot()
#table = pd.pivot_table(df, values='D', index=['A', 'B'],
#                    columns=['C'], aggfunc=np.sum)

#df.groupby('Gender')[['Count']].sum().plot(legend=True)

# %%
#Ex20
both_df = df.pivot_table(index="Name", columns="Gender", values="Count", aggfunc=np.sum).dropna()
both_df.index.nunique()
# Out:
# 10221

# %%
#22
df["Year"].max()
print(df["Year"].max() - df["Year"].min())
# Out:
# 134

# %%
#24
df["Count"].min()
ex = df[df["Count"]==5]
max_val= ex.groupby("Name")[["Count"]].sum().max()
max_val#160
frame = ex.groupby("Name")[["Count"]].sum()
frame[frame["Count"]==160]
# Out:
#           Count
# Name
# Celester    160

# %%
#25
a = df[(df["Name"]=='John')|(df["Name"]=='Mary')]
total_births = pd.pivot_table(a,index='Year', columns='Name',values='Count',  aggfunc=sum).plot()
#table = pd.pivot_table(df, values='D', index=['A', 'B'],
#                    columns=['C'], aggfunc=np.sum)

# %%
b =df[((df["Name"]=='John')&(df["Gender"]=='F'))|((df["Name"]=='Mary')&(df["Gender"]=='M'))]
total_births = pd.pivot_table(b,index='Year', columns='Name',values='Count',  aggfunc=sum).plot()
